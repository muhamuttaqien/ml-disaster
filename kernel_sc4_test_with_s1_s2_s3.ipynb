# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

import torch
import torch.nn as nn
import torch.nn.functional as F

from sklearn.metrics import mean_absolute_error, mean_squared_error

# %%
plt.style.use('ggplot')

# %% [markdown]
# ## Load Data

# %%
data_path = "./per_station.xlsx"
data = pd.read_excel(data_path)

# Extract the 'sc4' column data
sc_data = data['sc4'].values

# %%
# Generate dummy data
series_data = sc_data[:]

# Plot the dummy data
plt.figure(figsize=(10, 6))
plt.plot(series_data, linestyle='-')
plt.title('Tsunami Simulation Data (Scenario 4)')
plt.xlabel('Period')
plt.ylabel('Attribute')
plt.grid(True)
plt.show()

# %% [markdown]
# ## Prepare Data

# %%
def prepare_data(data, seq_length):
    X, y = [], []
    for i in range(len(data) - seq_length):
        X.append(data[i:i+seq_length])
        y.append(data[i+seq_length])
    return np.array(X), np.array(y)

# Define sequence length
sequence_length = 20

# Prepare the data
X, y = prepare_data(series_data, sequence_length)

# Convert to PyTorch tensors
X_tensor = torch.Tensor(X).unsqueeze(-1)  # Add an extra dimension for the input channel
y_tensor = torch.Tensor(y).unsqueeze(-1)

# %% [markdown]
# ## LSTM Experiment

# %% [markdown]
# #### Build Model

# %%
class LSTMModel(nn.Module):
    def __init__(self, input_size, hidden_size, num_layers, output_size):
        super(LSTMModel, self).__init__()
        self.hidden_size = hidden_size
        self.num_layers = num_layers
        self.lstm = nn.LSTM(input_size, hidden_size, num_layers, batch_first=True)
        self.dropout = nn.Dropout(0.5)
        self.fc = nn.Linear(hidden_size, output_size)
    
    def forward(self, x):
        h0 = torch.zeros(self.num_layers, x.size(0), self.hidden_size).to(x.device)
        c0 = torch.zeros(self.num_layers, x.size(0), self.hidden_size).to(x.device)
        out, _ = self.lstm(x, (h0, c0))
        out = self.fc(out[:, -1, :])
        return out

# Define model parameters
input_size = 1
hidden_size = 32
num_layers = 2
output_size = 1

# Instantiate the model
model = LSTMModel(input_size, hidden_size, num_layers, output_size)
print(model)
# Out:
# LSTMModel(
#   (lstm): LSTM(1, 32, num_layers=2, batch_first=True)
#   (dropout): Dropout(p=0.5, inplace=False)
#   (fc): Linear(in_features=32, out_features=1, bias=True)
# )

# %% [markdown]
# #### Train Model

# %%
# Define training parameters
num_epochs = 200
learning_rate = 0.001
batch_size = 32
criterion = nn.MSELoss()
optimizer = torch.optim.Adam(model.parameters(), lr=learning_rate)

# Store losses
losses = []

# Initialize the best loss as infinity
best_loss = float('inf')

# Training loop
for epoch in range(num_epochs):
    
    epoch_loss = 0.0
    
    # Shuffle the data and split into batches
    indices = torch.randperm(len(X_tensor))
    X_shuffled = X_tensor[indices]
    y_shuffled = y_tensor[indices]
    
    for i in range(0, len(X_tensor), batch_size):
        
        # Forward pass
        outputs = model(X_shuffled[i:i+batch_size])
        loss = criterion(outputs, y_shuffled[i:i+batch_size])
        
        # Backward pass and optimization
        optimizer.zero_grad()
        loss.backward()
        optimizer.step()
        
        # Accumulate loss for the epoch
        epoch_loss += loss.item()
    
    # Average epoch loss
    epoch_loss /= (len(X_tensor) / batch_size)
    losses.append(epoch_loss)
    
    # Save the model if this epoch's loss is the best we've seen so far
    if epoch_loss < best_loss:
        best_loss = epoch_loss
        torch.save(model.state_dict(), 'best_model.pth')

    if (epoch+1) % 1 == 0:
        print(f'Epoch [{epoch+1}/{num_epochs}], MSE Loss: {epoch_loss:.6f}')
# Out:
# Epoch [1/200], MSE Loss: 19.449359
# Epoch [2/200], MSE Loss: 0.398527
# Epoch [3/200], MSE Loss: 0.314254
# Epoch [4/200], MSE Loss: 0.282556
# Epoch [5/200], MSE Loss: 0.265057
# Epoch [6/200], MSE Loss: 0.242156
# Epoch [7/200], MSE Loss: 0.223291
# Epoch [8/200], MSE Loss: 0.204325
# Epoch [9/200], MSE Loss: 0.185895
# Epoch [10/200], MSE Loss: 0.170772
# Epoch [11/200], MSE Loss: 0.151074
# Epoch [12/200], MSE Loss: 0.134345
# Epoch [13/200], MSE Loss: 0.118552
# Epoch [14/200], MSE Loss: 0.104683
# Epoch [15/200], MSE Loss: 0.100731
# Epoch [16/200], MSE Loss: 0.076987
# Epoch [17/200], MSE Loss: 0.067227
# Epoch [18/200], MSE Loss: 0.054996
# Epoch [19/200], MSE Loss: 0.045961
# Epoch [20/200], MSE Loss: 0.036662
# Epoch [21/200], MSE Loss: 0.030357
# Epoch [22/200], MSE Loss: 0.023909
# Epoch [23/200], MSE Loss: 0.019406
# Epoch [24/200], MSE Loss: 0.017258
# Epoch [25/200], MSE Loss: 0.011162
# Epoch [26/200], MSE Loss: 0.009151
# Epoch [27/200], MSE Loss: 0.012274
# Epoch [28/200], MSE Loss: 0.015571
# Epoch [29/200], MSE Loss: 0.010903
# Epoch [30/200], MSE Loss: 0.006617
# Epoch [31/200], MSE Loss: 0.005058
# Epoch [32/200], MSE Loss: 0.004124
# Epoch [33/200], MSE Loss: 0.005302
# Epoch [34/200], MSE Loss: 0.004118
# Epoch [35/200], MSE Loss: 0.009739
# Epoch [36/200], MSE Loss: 0.006946
# Epoch [37/200], MSE Loss: 0.004586
# Epoch [38/200], MSE Loss: 0.005043
# Epoch [39/200], MSE Loss: 0.006258
# Epoch [40/200], MSE Loss: 0.011918
# Epoch [41/200], MSE Loss: 0.004565
# Epoch [42/200], MSE Loss: 0.002903
# Epoch [43/200], MSE Loss: 0.003769
# Epoch [44/200], MSE Loss: 0.003829
# Epoch [45/200], MSE Loss: 0.003526
# Epoch [46/200], MSE Loss: 0.003671
# Epoch [47/200], MSE Loss: 0.004026
# Epoch [48/200], MSE Loss: 0.005460
# Epoch [49/200], MSE Loss: 0.003446
# Epoch [50/200], MSE Loss: 0.003978
# Epoch [51/200], MSE Loss: 0.003112
# Epoch [52/200], MSE Loss: 0.002964
# Epoch [53/200], MSE Loss: 0.004107
# Epoch [54/200], MSE Loss: 0.002706
# Epoch [55/200], MSE Loss: 0.005922
# Epoch [56/200], MSE Loss: 0.003453
# Epoch [57/200], MSE Loss: 0.004589
# Epoch [58/200], MSE Loss: 0.003479
# Epoch [59/200], MSE Loss: 0.003302
# Epoch [60/200], MSE Loss: 0.003414
# Epoch [61/200], MSE Loss: 0.003458
# Epoch [62/200], MSE Loss: 0.003229
# Epoch [63/200], MSE Loss: 0.003637
# Epoch [64/200], MSE Loss: 0.003028
# Epoch [65/200], MSE Loss: 0.003232
# Epoch [66/200], MSE Loss: 0.002572
# Epoch [67/200], MSE Loss: 0.003175
# Epoch [68/200], MSE Loss: 0.003701
# Epoch [69/200], MSE Loss: 0.004471
# Epoch [70/200], MSE Loss: 0.003238
# Epoch [71/200], MSE Loss: 0.003676
# Epoch [72/200], MSE Loss: 0.002773
# Epoch [73/200], MSE Loss: 0.004036
# Epoch [74/200], MSE Loss: 0.003063
# Epoch [75/200], MSE Loss: 0.002584
# Epoch [76/200], MSE Loss: 0.001780
# Epoch [77/200], MSE Loss: 0.004322
# Epoch [78/200], MSE Loss: 0.003048
# Epoch [79/200], MSE Loss: 0.003055
# Epoch [80/200], MSE Loss: 0.002983
# Epoch [81/200], MSE Loss: 0.005488
# Epoch [82/200], MSE Loss: 0.003279
# Epoch [83/200], MSE Loss: 0.002440
# Epoch [84/200], MSE Loss: 0.003238
# Epoch [85/200], MSE Loss: 0.003172
# Epoch [86/200], MSE Loss: 0.003277
# Epoch [87/200], MSE Loss: 0.002898
# Epoch [88/200], MSE Loss: 0.002452
# Epoch [89/200], MSE Loss: 0.003595
# Epoch [90/200], MSE Loss: 0.003857
# Epoch [91/200], MSE Loss: 0.002977
# Epoch [92/200], MSE Loss: 0.003060
# Epoch [93/200], MSE Loss: 0.003022
# Epoch [94/200], MSE Loss: 0.003413
# Epoch [95/200], MSE Loss: 0.002160
# Epoch [96/200], MSE Loss: 0.003783
# Epoch [97/200], MSE Loss: 0.003634
# Epoch [98/200], MSE Loss: 0.003193
# Epoch [99/200], MSE Loss: 0.003085
# Epoch [100/200], MSE Loss: 0.003104
# Epoch [101/200], MSE Loss: 0.003090
# Epoch [102/200], MSE Loss: 0.003067
# Epoch [103/200], MSE Loss: 0.002812
# Epoch [104/200], MSE Loss: 0.002887
# Epoch [105/200], MSE Loss: 0.004092
# Epoch [106/200], MSE Loss: 0.002638
# Epoch [107/200], MSE Loss: 0.002591
# Epoch [108/200], MSE Loss: 0.002536
# Epoch [109/200], MSE Loss: 0.002270
# Epoch [110/200], MSE Loss: 0.003361
# Epoch [111/200], MSE Loss: 0.005785
# Epoch [112/200], MSE Loss: 0.002944
# Epoch [113/200], MSE Loss: 0.002704
# Epoch [114/200], MSE Loss: 0.002293
# Epoch [115/200], MSE Loss: 0.002722
# Epoch [116/200], MSE Loss: 0.002693
# Epoch [117/200], MSE Loss: 0.003315
# Epoch [118/200], MSE Loss: 0.003334
# Epoch [119/200], MSE Loss: 0.003091
# Epoch [120/200], MSE Loss: 0.003007
# Epoch [121/200], MSE Loss: 0.002747
# Epoch [122/200], MSE Loss: 0.002849
# Epoch [123/200], MSE Loss: 0.003290
# Epoch [124/200], MSE Loss: 0.003135
# Epoch [125/200], MSE Loss: 0.002991
# Epoch [126/200], MSE Loss: 0.003684
# Epoch [127/200], MSE Loss: 0.004560
# Epoch [128/200], MSE Loss: 0.002438
# Epoch [129/200], MSE Loss: 0.002472
# Epoch [130/200], MSE Loss: 0.003308
# Epoch [131/200], MSE Loss: 0.002512
# Epoch [132/200], MSE Loss: 0.002790
# Epoch [133/200], MSE Loss: 0.003341
# Epoch [134/200], MSE Loss: 0.002844
# Epoch [135/200], MSE Loss: 0.003090
# Epoch [136/200], MSE Loss: 0.004937
# Epoch [137/200], MSE Loss: 0.002516
# Epoch [138/200], MSE Loss: 0.002871
# Epoch [139/200], MSE Loss: 0.003064
# Epoch [140/200], MSE Loss: 0.002287
# Epoch [141/200], MSE Loss: 0.002663
# Epoch [142/200], MSE Loss: 0.003438
# Epoch [143/200], MSE Loss: 0.002299
# Epoch [144/200], MSE Loss: 0.002681
# Epoch [145/200], MSE Loss: 0.002710
# Epoch [146/200], MSE Loss: 0.002595
# Epoch [147/200], MSE Loss: 0.002911
# Epoch [148/200], MSE Loss: 0.002874
# Epoch [149/200], MSE Loss: 0.002749
# Epoch [150/200], MSE Loss: 0.003663
# Epoch [151/200], MSE Loss: 0.002384
# Epoch [152/200], MSE Loss: 0.003230
# Epoch [153/200], MSE Loss: 0.002917
# Epoch [154/200], MSE Loss: 0.002362
# Epoch [155/200], MSE Loss: 0.002196
# Epoch [156/200], MSE Loss: 0.002594
# Epoch [157/200], MSE Loss: 0.003170
# Epoch [158/200], MSE Loss: 0.002715
# Epoch [159/200], MSE Loss: 0.002636
# Epoch [160/200], MSE Loss: 0.003332
# Epoch [161/200], MSE Loss: 0.002216
# Epoch [162/200], MSE Loss: 0.001950
# Epoch [163/200], MSE Loss: 0.002699
# Epoch [164/200], MSE Loss: 0.001836
# Epoch [165/200], MSE Loss: 0.003164
# Epoch [166/200], MSE Loss: 0.003293
# Epoch [167/200], MSE Loss: 0.003368
# Epoch [168/200], MSE Loss: 0.003160
# Epoch [169/200], MSE Loss: 0.002694
# Epoch [170/200], MSE Loss: 0.002629
# Epoch [171/200], MSE Loss: 0.002798
# Epoch [172/200], MSE Loss: 0.002560
# Epoch [173/200], MSE Loss: 0.002898
# Epoch [174/200], MSE Loss: 0.003306
# Epoch [175/200], MSE Loss: 0.002859
# Epoch [176/200], MSE Loss: 0.003109
# Epoch [177/200], MSE Loss: 0.002285
# Epoch [178/200], MSE Loss: 0.002497
# Epoch [179/200], MSE Loss: 0.002828
# Epoch [180/200], MSE Loss: 0.002673
# Epoch [181/200], MSE Loss: 0.003282
# Epoch [182/200], MSE Loss: 0.002086
# Epoch [183/200], MSE Loss: 0.002633
# Epoch [184/200], MSE Loss: 0.002252
# Epoch [185/200], MSE Loss: 0.002644
# Epoch [186/200], MSE Loss: 0.002261
# Epoch [187/200], MSE Loss: 0.002365
# Epoch [188/200], MSE Loss: 0.002264
# Epoch [189/200], MSE Loss: 0.003299
# Epoch [190/200], MSE Loss: 0.002753
# Epoch [191/200], MSE Loss: 0.002377
# Epoch [192/200], MSE Loss: 0.002492
# Epoch [193/200], MSE Loss: 0.002588
# Epoch [194/200], MSE Loss: 0.003426
# Epoch [195/200], MSE Loss: 0.002957
# Epoch [196/200], MSE Loss: 0.002393
# Epoch [197/200], MSE Loss: 0.002562
# Epoch [198/200], MSE Loss: 0.002423
# Epoch [199/200], MSE Loss: 0.002247
# Epoch [200/200], MSE Loss: 0.002842

# %%
# Plot learning curve
offset = 30

plt.figure(figsize=(10, 6))
plt.plot(range(offset+1, num_epochs+1), losses[offset:], linestyle='-')
plt.title('Training Loss Curve')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.grid(True)
plt.show()

# %% [markdown]
# #### Evaluate Model

# %%
# Prepare the first sequence for prediction
first_sequence = torch.FloatTensor(series_data[:sequence_length]).unsqueeze(0).unsqueeze(-1)

# Make predictions for the entire time series
with torch.no_grad():
    future_periods = len(series_data) - sequence_length
    future_data = series_data[:sequence_length].tolist()

    for i in range(future_periods):
        pred = model(first_sequence)
        future_data.append(pred.item())
        
        # Update the first sequence for the next prediction
        # first_sequence = torch.cat((first_sequence[:, 1:, :], pred.unsqueeze(-1)), dim=1)
        first_sequence = torch.cat((first_sequence[:, 1:, :], torch.tensor([[series_data[i+sequence_length]]], dtype=torch.float32).unsqueeze(0)), dim=1)
        
# Plot the original and predicted simulation data
plt.figure(figsize=(10, 6))
plt.plot(np.arange(len(series_data)), series_data, linestyle='-', label='Simulation Data')
plt.plot(np.arange(len(series_data)), future_data, linestyle='--', color='g', label='Predicted Data')
plt.title('Tsunami Simulation Data Prediction with LSTM')
plt.xlabel('Period')
plt.ylabel('Attribute')
plt.legend()
plt.grid(True)
plt.show()

# %%
# Plot the original and predicted simulation data
plt.figure(figsize=(10, 6))
plt.plot(np.arange(len(series_data[:3000])), series_data[:3000], linestyle='-', label='Simulation Data')
plt.plot(np.arange(len(series_data[:3000])), future_data[:3000], linestyle='--', color='g', label='Predicted Data')
plt.title('Tsunami Simulation Data Prediction with LSTM')
plt.xlabel('Period')
plt.ylabel('Attribute')
plt.legend()
plt.grid(True)
plt.show()

# %%
# Calculate Mean Squared Error (MSE)
mse = mean_squared_error(series_data[sequence_length:], future_data[sequence_length:])
print("Mean Squared Error (MSE):", mse)

# Calculate Mean Absolute Error (MAE)
mae = mean_absolute_error(series_data[sequence_length:], future_data[sequence_length:])
print("Mean Absolute Error (MAE):", mae)
# Out:
# Mean Squared Error (MSE): 0.0012411389617630673
# Mean Absolute Error (MAE): 0.00380184580823876

# %% [markdown]
# ## Test S1, S2, S3

# %%
sc_data = data['sc1'].values
series_data = sc_data[:]

# %%
# Prepare the first sequence for prediction
first_sequence = torch.FloatTensor(series_data[:sequence_length]).unsqueeze(0).unsqueeze(-1)

# Make predictions for the entire time series
with torch.no_grad():
    future_periods = len(series_data) - sequence_length
    future_data = series_data[:sequence_length].tolist()

    for i in range(future_periods):
        pred = model(first_sequence)
        future_data.append(pred.item())
        
        # Update the first sequence for the next prediction
        # first_sequence = torch.cat((first_sequence[:, 1:, :], pred.unsqueeze(-1)), dim=1)
        first_sequence = torch.cat((first_sequence[:, 1:, :], torch.tensor([[series_data[i+sequence_length]]], dtype=torch.float32).unsqueeze(0)), dim=1)
        
# Plot the original and predicted simulation data
plt.figure(figsize=(10, 6))
plt.plot(np.arange(len(series_data)), series_data, linestyle='-', label='Simulation Data')
plt.plot(np.arange(len(series_data)), future_data, linestyle='--', color='g', label='Predicted Data')
plt.title('Tsunami Simulation Data Prediction with LSTM (SC1)')
plt.xlabel('Period')
plt.ylabel('Attribute')
plt.legend()
plt.grid(True)
plt.show()

# Plot the original and predicted simulation data
plt.figure(figsize=(10, 6))
plt.plot(np.arange(len(series_data[:3000])), series_data[:3000], linestyle='-', label='Simulation Data')
plt.plot(np.arange(len(series_data[:3000])), future_data[:3000], linestyle='--', color='g', label='Predicted Data')
plt.title('Tsunami Simulation Data Prediction with LSTM (SC1)')
plt.xlabel('Period')
plt.ylabel('Attribute')
plt.legend()
plt.grid(True)
plt.show()

# %%
# Calculate Mean Squared Error (MSE)
mse = mean_squared_error(series_data[sequence_length:], future_data[sequence_length:])
print("SC1 Mean Squared Error (MSE):", mse)

# Calculate Mean Absolute Error (MAE)
mae = mean_absolute_error(series_data[sequence_length:], future_data[sequence_length:])
print("SC1 Mean Absolute Error (MAE):", mae)
# Out:
# SC1 Mean Squared Error (MSE): 0.00693325287903361
# SC1 Mean Absolute Error (MAE): 0.006863594534823524

# %%
sc_data = data['sc2'].values
series_data = sc_data[:]

# %%
# Prepare the first sequence for prediction
first_sequence = torch.FloatTensor(series_data[:sequence_length]).unsqueeze(0).unsqueeze(-1)

# Make predictions for the entire time series
with torch.no_grad():
    future_periods = len(series_data) - sequence_length
    future_data = series_data[:sequence_length].tolist()

    for i in range(future_periods):
        pred = model(first_sequence)
        future_data.append(pred.item())
        
        # Update the first sequence for the next prediction
        # first_sequence = torch.cat((first_sequence[:, 1:, :], pred.unsqueeze(-1)), dim=1)
        first_sequence = torch.cat((first_sequence[:, 1:, :], torch.tensor([[series_data[i+sequence_length]]], dtype=torch.float32).unsqueeze(0)), dim=1)
        
# Plot the original and predicted simulation data
plt.figure(figsize=(10, 6))
plt.plot(np.arange(len(series_data)), series_data, linestyle='-', label='Simulation Data')
plt.plot(np.arange(len(series_data)), future_data, linestyle='--', color='g', label='Predicted Data')
plt.title('Tsunami Simulation Data Prediction with LSTM (SC2)')
plt.xlabel('Period')
plt.ylabel('Attribute')
plt.legend()
plt.grid(True)
plt.show()

# Plot the original and predicted simulation data
plt.figure(figsize=(10, 6))
plt.plot(np.arange(len(series_data[:3000])), series_data[:3000], linestyle='-', label='Simulation Data')
plt.plot(np.arange(len(series_data[:3000])), future_data[:3000], linestyle='--', color='g', label='Predicted Data')
plt.title('Tsunami Simulation Data Prediction with LSTM (SC2)')
plt.xlabel('Period')
plt.ylabel('Attribute')
plt.legend()
plt.grid(True)
plt.show()

# %%
# Calculate Mean Squared Error (MSE)
mse = mean_squared_error(series_data[sequence_length:], future_data[sequence_length:])
print("SC2 Mean Squared Error (MSE):", mse)

# Calculate Mean Absolute Error (MAE)
mae = mean_absolute_error(series_data[sequence_length:], future_data[sequence_length:])
print("SC2 Mean Absolute Error (MAE):", mae)
# Out:
# SC2 Mean Squared Error (MSE): 0.010258328099772762
# SC2 Mean Absolute Error (MAE): 0.010753607824126148

# %%
sc_data = data['sc3'].values
series_data = sc_data[:]

# %%
# Prepare the first sequence for prediction
first_sequence = torch.FloatTensor(series_data[:sequence_length]).unsqueeze(0).unsqueeze(-1)

# Make predictions for the entire time series
with torch.no_grad():
    future_periods = len(series_data) - sequence_length
    future_data = series_data[:sequence_length].tolist()

    for i in range(future_periods):
        pred = model(first_sequence)
        future_data.append(pred.item())
        
        # Update the first sequence for the next prediction
        # first_sequence = torch.cat((first_sequence[:, 1:, :], pred.unsqueeze(-1)), dim=1)
        first_sequence = torch.cat((first_sequence[:, 1:, :], torch.tensor([[series_data[i+sequence_length]]], dtype=torch.float32).unsqueeze(0)), dim=1)
        
# Plot the original and predicted simulation data
plt.figure(figsize=(10, 6))
plt.plot(np.arange(len(series_data)), series_data, linestyle='-', label='Simulation Data')
plt.plot(np.arange(len(series_data)), future_data, linestyle='--', color='g', label='Predicted Data')
plt.title('Tsunami Simulation Data Prediction with LSTM (SC3)')
plt.xlabel('Period')
plt.ylabel('Attribute')
plt.legend()
plt.grid(True)
plt.show()

# Plot the original and predicted simulation data
plt.figure(figsize=(10, 6))
plt.plot(np.arange(len(series_data[:3000])), series_data[:3000], linestyle='-', label='Simulation Data')
plt.plot(np.arange(len(series_data[:3000])), future_data[:3000], linestyle='--', color='g', label='Predicted Data')
plt.title('Tsunami Simulation Data Prediction with LSTM (SC3)')
plt.xlabel('Period')
plt.ylabel('Attribute')
plt.legend()
plt.grid(True)
plt.show()

# %%
# Calculate Mean Squared Error (MSE)
mse = mean_squared_error(series_data[sequence_length:], future_data[sequence_length:])
print("SC3 Mean Squared Error (MSE):", mse)

# Calculate Mean Absolute Error (MAE)
mae = mean_absolute_error(series_data[sequence_length:], future_data[sequence_length:])
print("SC3 Mean Absolute Error (MAE):", mae)
# Out:
# SC3 Mean Squared Error (MSE): 0.07904311475762449
# SC3 Mean Absolute Error (MAE): 0.02487524211391811

# %% [markdown]
# ---
