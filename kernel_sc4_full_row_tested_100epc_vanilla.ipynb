# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

import torch
import torch.nn as nn
import torch.nn.functional as F

from sklearn.metrics import mean_absolute_error, mean_squared_error

# %%
plt.style.use('ggplot')

# %% [markdown]
# ## Load Data

# %%
data_path = "./per_station.xlsx"
data = pd.read_excel(data_path)

# Extract the 'sc4' column data
sc_data = data['sc4'].values

# %%
# Generate dummy data
series_data = sc_data[:]

# Plot the dummy data
plt.figure(figsize=(10, 6))
plt.plot(series_data, linestyle='-')
plt.title('Tsunami Simulation Data (Scenario 4)')
plt.xlabel('Period')
plt.ylabel('Attribute')
plt.grid(True)
plt.show()

# %% [markdown]
# ## Prepare Data

# %%
def prepare_data(data, seq_length):
    X, y = [], []
    for i in range(len(data) - seq_length):
        X.append(data[i:i+seq_length])
        y.append(data[i+seq_length])
    return np.array(X), np.array(y)

# Define sequence length
sequence_length = 20

# Prepare the data
X, y = prepare_data(series_data, sequence_length)

# Convert to PyTorch tensors
X_tensor = torch.Tensor(X).unsqueeze(-1)  # Add an extra dimension for the input channel
y_tensor = torch.Tensor(y).unsqueeze(-1)

# %% [markdown]
# ## LSTM Experiment

# %% [markdown]
# #### Build Model

# %%
class VanillaLSTM(nn.Module):
    def __init__(self, input_size, hidden_size, num_layers, output_size):
        super(VanillaLSTM, self).__init__()
        self.hidden_size = hidden_size
        self.num_layers = num_layers
        self.lstm = nn.LSTM(input_size, hidden_size, num_layers, batch_first=True)
        self.dropout = nn.Dropout(0.5)
        self.fc = nn.Linear(hidden_size, output_size)
    
    def forward(self, x):
        h0 = torch.zeros(self.num_layers, x.size(0), self.hidden_size).to(x.device)
        c0 = torch.zeros(self.num_layers, x.size(0), self.hidden_size).to(x.device)
        out, _ = self.lstm(x, (h0, c0))
        out = self.fc(out[:, -1, :])
        return out

# Define model parameters
input_size = 1
hidden_size = 32
num_layers = 2
output_size = 1

# Instantiate the model
model = VanillaLSTM(input_size, hidden_size, num_layers, output_size)
print(model)
# Out:
# VanillaLSTM(
#   (lstm): LSTM(1, 32, num_layers=2, batch_first=True)
#   (dropout): Dropout(p=0.5, inplace=False)
#   (fc): Linear(in_features=32, out_features=1, bias=True)
# )

# %% [markdown]
# #### Train Model

# %%
# Define training parameters
num_epochs = 100
learning_rate = 0.001
batch_size = 32
criterion = nn.MSELoss()
optimizer = torch.optim.Adam(model.parameters(), lr=learning_rate)

# Store losses
losses = []

# Initialize the best loss as infinity
best_loss = float('inf')

# Training loop
for epoch in range(num_epochs):
    
    epoch_loss = 0.0
    
    # Shuffle the data and split into batches
    indices = torch.randperm(len(X_tensor))
    X_shuffled = X_tensor[indices]
    y_shuffled = y_tensor[indices]
    
    for i in range(0, len(X_tensor), batch_size):
        
        # Forward pass
        outputs = model(X_shuffled[i:i+batch_size])
        loss = criterion(outputs, y_shuffled[i:i+batch_size])
        
        # Backward pass and optimization
        optimizer.zero_grad()
        loss.backward()
        optimizer.step()
        
        # Accumulate loss for the epoch
        epoch_loss += loss.item()
    
    # Average epoch loss
    epoch_loss /= (len(X_tensor) / batch_size)
    losses.append(epoch_loss)
    
    # Save the model if this epoch's loss is the best we've seen so far
    if epoch_loss < best_loss:
        best_loss = epoch_loss
        torch.save(model.state_dict(), 'best_model.pth')

    if (epoch+1) % 1 == 0:
        print(f'Epoch [{epoch+1}/{num_epochs}], MSE Loss: {epoch_loss:.6f}')
# Out:
# Epoch [1/100], MSE Loss: 18.539883
# Epoch [2/100], MSE Loss: 0.409341
# Epoch [3/100], MSE Loss: 0.323973
# Epoch [4/100], MSE Loss: 0.286852
# Epoch [5/100], MSE Loss: 0.262001
# Epoch [6/100], MSE Loss: 0.239554
# Epoch [7/100], MSE Loss: 0.219794
# Epoch [8/100], MSE Loss: 0.200166
# Epoch [9/100], MSE Loss: 0.183244
# Epoch [10/100], MSE Loss: 0.166497
# Epoch [11/100], MSE Loss: 0.148843
# Epoch [12/100], MSE Loss: 0.131974
# Epoch [13/100], MSE Loss: 0.117442
# Epoch [14/100], MSE Loss: 0.102255
# Epoch [15/100], MSE Loss: 0.086720
# Epoch [16/100], MSE Loss: 0.076815
# Epoch [17/100], MSE Loss: 0.065801
# Epoch [18/100], MSE Loss: 0.052785
# Epoch [19/100], MSE Loss: 0.044498
# Epoch [20/100], MSE Loss: 0.036413
# Epoch [21/100], MSE Loss: 0.037505
# Epoch [22/100], MSE Loss: 0.022714
# Epoch [23/100], MSE Loss: 0.018004
# Epoch [24/100], MSE Loss: 0.013825
# Epoch [25/100], MSE Loss: 0.013806
# Epoch [26/100], MSE Loss: 0.009679
# Epoch [27/100], MSE Loss: 0.007924
# Epoch [28/100], MSE Loss: 0.006381
# Epoch [29/100], MSE Loss: 0.004843
# Epoch [30/100], MSE Loss: 0.005471
# Epoch [31/100], MSE Loss: 0.003154
# Epoch [32/100], MSE Loss: 0.005895
# Epoch [33/100], MSE Loss: 0.007297
# Epoch [34/100], MSE Loss: 0.005874
# Epoch [35/100], MSE Loss: 0.004459
# Epoch [36/100], MSE Loss: 0.004981
# Epoch [37/100], MSE Loss: 0.007880
# Epoch [38/100], MSE Loss: 0.004358
# Epoch [39/100], MSE Loss: 0.004847
# Epoch [40/100], MSE Loss: 0.004238
# Epoch [41/100], MSE Loss: 0.003708
# Epoch [42/100], MSE Loss: 0.003005
# Epoch [43/100], MSE Loss: 0.004150
# Epoch [44/100], MSE Loss: 0.003260
# Epoch [45/100], MSE Loss: 0.004260
# Epoch [46/100], MSE Loss: 0.003372
# Epoch [47/100], MSE Loss: 0.003157
# Epoch [48/100], MSE Loss: 0.003162
# Epoch [49/100], MSE Loss: 0.004723
# Epoch [50/100], MSE Loss: 0.003802
# Epoch [51/100], MSE Loss: 0.003844
# Epoch [52/100], MSE Loss: 0.004047
# Epoch [53/100], MSE Loss: 0.003155
# Epoch [54/100], MSE Loss: 0.002849
# Epoch [55/100], MSE Loss: 0.003954
# Epoch [56/100], MSE Loss: 0.003569
# Epoch [57/100], MSE Loss: 0.003566
# Epoch [58/100], MSE Loss: 0.003835
# Epoch [59/100], MSE Loss: 0.003195
# Epoch [60/100], MSE Loss: 0.003166
# Epoch [61/100], MSE Loss: 0.003524
# Epoch [62/100], MSE Loss: 0.004470
# Epoch [63/100], MSE Loss: 0.003971
# Epoch [64/100], MSE Loss: 0.004110
# Epoch [65/100], MSE Loss: 0.003468
# Epoch [66/100], MSE Loss: 0.002905
# Epoch [67/100], MSE Loss: 0.002685
# Epoch [68/100], MSE Loss: 0.004206
# Epoch [69/100], MSE Loss: 0.004534
# Epoch [70/100], MSE Loss: 0.004242
# Epoch [71/100], MSE Loss: 0.003352
# Epoch [72/100], MSE Loss: 0.003241
# Epoch [73/100], MSE Loss: 0.002950
# Epoch [74/100], MSE Loss: 0.003015
# Epoch [75/100], MSE Loss: 0.003612
# Epoch [76/100], MSE Loss: 0.002788
# Epoch [77/100], MSE Loss: 0.003171
# Epoch [78/100], MSE Loss: 0.003463
# Epoch [79/100], MSE Loss: 0.003594
# Epoch [80/100], MSE Loss: 0.003226
# Epoch [81/100], MSE Loss: 0.003944
# Epoch [82/100], MSE Loss: 0.002851
# Epoch [83/100], MSE Loss: 0.004453
# Epoch [84/100], MSE Loss: 0.003177
# Epoch [85/100], MSE Loss: 0.003253
# Epoch [86/100], MSE Loss: 0.003272
# Epoch [87/100], MSE Loss: 0.002825
# Epoch [88/100], MSE Loss: 0.003446
# Epoch [89/100], MSE Loss: 0.003336
# Epoch [90/100], MSE Loss: 0.003295
# Epoch [91/100], MSE Loss: 0.003141
# Epoch [92/100], MSE Loss: 0.002699
# Epoch [93/100], MSE Loss: 0.003369
# Epoch [94/100], MSE Loss: 0.003350
# Epoch [95/100], MSE Loss: 0.003991
# Epoch [96/100], MSE Loss: 0.002620
# Epoch [97/100], MSE Loss: 0.002575
# Epoch [98/100], MSE Loss: 0.002276
# Epoch [99/100], MSE Loss: 0.002820
# Epoch [100/100], MSE Loss: 0.003785

# %%
# Plot learning curve
offset = 30

plt.figure(figsize=(10, 6))
plt.plot(range(offset+1, num_epochs+1), losses[offset:], linestyle='-')
plt.title('Training Loss Curve')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.grid(True)
plt.show()

# %% [markdown]
# #### Evaluate Model

# %%
# Prepare the first sequence for prediction
first_sequence = torch.FloatTensor(series_data[:sequence_length]).unsqueeze(0).unsqueeze(-1)

# Make predictions for the entire time series
with torch.no_grad():
    future_periods = len(series_data) - sequence_length
    future_data = series_data[:sequence_length].tolist()

    for i in range(future_periods):
        pred = model(first_sequence)
        future_data.append(pred.item())
        
        # Update the first sequence for the next prediction
        # first_sequence = torch.cat((first_sequence[:, 1:, :], pred.unsqueeze(-1)), dim=1)
        first_sequence = torch.cat((first_sequence[:, 1:, :], torch.tensor([[series_data[i+sequence_length]]], dtype=torch.float32).unsqueeze(0)), dim=1)
        
# Plot the original and predicted simulation data
plt.figure(figsize=(10, 6))
plt.plot(np.arange(len(series_data)), series_data, linestyle='-', label='Simulation Data')
plt.plot(np.arange(len(series_data)), future_data, linestyle='--', color='g', label='Predicted Data')
plt.title('Tsunami Simulation Data Prediction with LSTM')
plt.xlabel('Period')
plt.ylabel('Attribute')
plt.legend()
plt.grid(True)
plt.show()

# %%
# Plot the original and predicted simulation data
plt.figure(figsize=(10, 6))
plt.plot(np.arange(len(series_data[:3000])), series_data[:3000], linestyle='-', label='Simulation Data')
plt.plot(np.arange(len(series_data[:3000])), future_data[:3000], linestyle='--', color='g', label='Predicted Data')
plt.title('Tsunami Simulation Data Prediction with LSTM')
plt.xlabel('Period')
plt.ylabel('Attribute')
plt.legend()
plt.grid(True)
plt.show()

# %%
# Calculate Mean Squared Error (MSE)
mse = mean_squared_error(series_data[sequence_length:], future_data[sequence_length:])
print("Mean Squared Error (MSE):", mse)

# Calculate Mean Absolute Error (MAE)
mae = mean_absolute_error(series_data[sequence_length:], future_data[sequence_length:])
print("Mean Absolute Error (MAE):", mae)
# Out:
# Mean Squared Error (MSE): 0.0016833358064477135
# Mean Absolute Error (MAE): 0.0075486626752757245

# %% [markdown]
# ## Test S1, S2, S3

# %%
sc_data = data['sc1'].values
series_data = sc_data[:]

# %%
# Prepare the first sequence for prediction
first_sequence = torch.FloatTensor(series_data[:sequence_length]).unsqueeze(0).unsqueeze(-1)

# Make predictions for the entire time series
with torch.no_grad():
    future_periods = len(series_data) - sequence_length
    future_data = series_data[:sequence_length].tolist()

    for i in range(future_periods):
        pred = model(first_sequence)
        future_data.append(pred.item())
        
        # Update the first sequence for the next prediction
        # first_sequence = torch.cat((first_sequence[:, 1:, :], pred.unsqueeze(-1)), dim=1)
        first_sequence = torch.cat((first_sequence[:, 1:, :], torch.tensor([[series_data[i+sequence_length]]], dtype=torch.float32).unsqueeze(0)), dim=1)
        
# Plot the original and predicted simulation data
plt.figure(figsize=(10, 6))
plt.plot(np.arange(len(series_data)), series_data, linestyle='-', label='Simulation Data')
plt.plot(np.arange(len(series_data)), future_data, linestyle='--', color='g', label='Predicted Data')
plt.title('Tsunami Simulation Data Prediction with LSTM (SC1)')
plt.xlabel('Period')
plt.ylabel('Attribute')
plt.legend()
plt.grid(True)
plt.show()

# Plot the original and predicted simulation data
plt.figure(figsize=(10, 6))
plt.plot(np.arange(len(series_data[:3000])), series_data[:3000], linestyle='-', label='Simulation Data')
plt.plot(np.arange(len(series_data[:3000])), future_data[:3000], linestyle='--', color='g', label='Predicted Data')
plt.title('Tsunami Simulation Data Prediction with LSTM (SC1)')
plt.xlabel('Period')
plt.ylabel('Attribute')
plt.legend()
plt.grid(True)
plt.show()

# %%
# Calculate Mean Squared Error (MSE)
mse = mean_squared_error(series_data[sequence_length:], future_data[sequence_length:])
print("SC1 Mean Squared Error (MSE):", mse)

# Calculate Mean Absolute Error (MAE)
mae = mean_absolute_error(series_data[sequence_length:], future_data[sequence_length:])
print("SC1 Mean Absolute Error (MAE):", mae)
# Out:
# SC1 Mean Squared Error (MSE): 0.004561015096088798
# SC1 Mean Absolute Error (MAE): 0.009379686062871064

# %%
sc_data = data['sc2'].values
series_data = sc_data[:]

# %%
# Prepare the first sequence for prediction
first_sequence = torch.FloatTensor(series_data[:sequence_length]).unsqueeze(0).unsqueeze(-1)

# Make predictions for the entire time series
with torch.no_grad():
    future_periods = len(series_data) - sequence_length
    future_data = series_data[:sequence_length].tolist()

    for i in range(future_periods):
        pred = model(first_sequence)
        future_data.append(pred.item())
        
        # Update the first sequence for the next prediction
        # first_sequence = torch.cat((first_sequence[:, 1:, :], pred.unsqueeze(-1)), dim=1)
        first_sequence = torch.cat((first_sequence[:, 1:, :], torch.tensor([[series_data[i+sequence_length]]], dtype=torch.float32).unsqueeze(0)), dim=1)
        
# Plot the original and predicted simulation data
plt.figure(figsize=(10, 6))
plt.plot(np.arange(len(series_data)), series_data, linestyle='-', label='Simulation Data')
plt.plot(np.arange(len(series_data)), future_data, linestyle='--', color='g', label='Predicted Data')
plt.title('Tsunami Simulation Data Prediction with LSTM (SC2)')
plt.xlabel('Period')
plt.ylabel('Attribute')
plt.legend()
plt.grid(True)
plt.show()

# Plot the original and predicted simulation data
plt.figure(figsize=(10, 6))
plt.plot(np.arange(len(series_data[:3000])), series_data[:3000], linestyle='-', label='Simulation Data')
plt.plot(np.arange(len(series_data[:3000])), future_data[:3000], linestyle='--', color='g', label='Predicted Data')
plt.title('Tsunami Simulation Data Prediction with LSTM (SC2)')
plt.xlabel('Period')
plt.ylabel('Attribute')
plt.legend()
plt.grid(True)
plt.show()

# %%
# Calculate Mean Squared Error (MSE)
mse = mean_squared_error(series_data[sequence_length:], future_data[sequence_length:])
print("SC2 Mean Squared Error (MSE):", mse)

# Calculate Mean Absolute Error (MAE)
mae = mean_absolute_error(series_data[sequence_length:], future_data[sequence_length:])
print("SC2 Mean Absolute Error (MAE):", mae)
# Out:
# SC2 Mean Squared Error (MSE): 0.008014761080258722
# SC2 Mean Absolute Error (MAE): 0.013191426060315673

# %%
sc_data = data['sc3'].values
series_data = sc_data[:]

# %%
# Prepare the first sequence for prediction
first_sequence = torch.FloatTensor(series_data[:sequence_length]).unsqueeze(0).unsqueeze(-1)

# Make predictions for the entire time series
with torch.no_grad():
    future_periods = len(series_data) - sequence_length
    future_data = series_data[:sequence_length].tolist()

    for i in range(future_periods):
        pred = model(first_sequence)
        future_data.append(pred.item())
        
        # Update the first sequence for the next prediction
        # first_sequence = torch.cat((first_sequence[:, 1:, :], pred.unsqueeze(-1)), dim=1)
        first_sequence = torch.cat((first_sequence[:, 1:, :], torch.tensor([[series_data[i+sequence_length]]], dtype=torch.float32).unsqueeze(0)), dim=1)
        
# Plot the original and predicted simulation data
plt.figure(figsize=(10, 6))
plt.plot(np.arange(len(series_data)), series_data, linestyle='-', label='Simulation Data')
plt.plot(np.arange(len(series_data)), future_data, linestyle='--', color='g', label='Predicted Data')
plt.title('Tsunami Simulation Data Prediction with LSTM (SC3)')
plt.xlabel('Period')
plt.ylabel('Attribute')
plt.legend()
plt.grid(True)
plt.show()

# Plot the original and predicted simulation data
plt.figure(figsize=(10, 6))
plt.plot(np.arange(len(series_data[:3000])), series_data[:3000], linestyle='-', label='Simulation Data')
plt.plot(np.arange(len(series_data[:3000])), future_data[:3000], linestyle='--', color='g', label='Predicted Data')
plt.title('Tsunami Simulation Data Prediction with LSTM (SC3)')
plt.xlabel('Period')
plt.ylabel('Attribute')
plt.legend()
plt.grid(True)
plt.show()

# %%
# Calculate Mean Squared Error (MSE)
mse = mean_squared_error(series_data[sequence_length:], future_data[sequence_length:])
print("SC3 Mean Squared Error (MSE):", mse)

# Calculate Mean Absolute Error (MAE)
mae = mean_absolute_error(series_data[sequence_length:], future_data[sequence_length:])
print("SC3 Mean Absolute Error (MAE):", mae)
# Out:
# SC3 Mean Squared Error (MSE): 0.04163472461724565
# SC3 Mean Absolute Error (MAE): 0.021675124389325465

# %% [markdown]
# ---
