# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

import torch
import torch.nn as nn
import torch.nn.functional as F

from sklearn.metrics import mean_absolute_error, mean_squared_error
# Out:
# /home/muttaqien-m/anaconda3/envs/thesis/lib/python3.10/site-packages/scipy/__init__.py:146: UserWarning: A NumPy version >=1.17.3 and <1.25.0 is required for this version of SciPy (detected version 1.26.4
#   warnings.warn(f"A NumPy version >={np_minversion} and <{np_maxversion}"

# %%
plt.style.use('ggplot')

# %% [markdown]
# ## Load Data

# %%
data_path = "./per_station.xlsx"
data = pd.read_excel(data_path)

# Extract the 'sc1' column data
sc_data = data['sc1'].values

# %%
# Generate dummy sales data
series_data = sc_data[:3000]

# Plot the dummy sales data
plt.figure(figsize=(10, 6))
plt.plot(series_data, linestyle='-')
plt.title('Tsunami Simulation Data (Scenario 1)')
plt.xlabel('Period')
plt.ylabel('Attribute')
plt.grid(True)
plt.show()

# %% [markdown]
# ## Prepare Data

# %%
def prepare_data(data, seq_length):
    X, y = [], []
    for i in range(len(data) - seq_length):
        X.append(data[i:i+seq_length])
        y.append(data[i+seq_length])
    return np.array(X), np.array(y)

# Define sequence length
sequence_length = 20

# Prepare the data
X, y = prepare_data(series_data, sequence_length)

# Convert to PyTorch tensors
X_tensor = torch.Tensor(X).unsqueeze(-1)  # Add an extra dimension for the input channel
y_tensor = torch.Tensor(y).unsqueeze(-1)

# %% [markdown]
# ## LSTM Experiment

# %% [markdown]
# #### Build Model

# %%
class LSTMModel(nn.Module):
    def __init__(self, input_size, hidden_size, num_layers, output_size):
        super(LSTMModel, self).__init__()
        self.hidden_size = hidden_size
        self.num_layers = num_layers
        self.lstm = nn.LSTM(input_size, hidden_size, num_layers, batch_first=True)
        self.fc = nn.Linear(hidden_size, output_size)
    
    def forward(self, x):
        h0 = torch.zeros(self.num_layers, x.size(0), self.hidden_size).to(x.device)
        c0 = torch.zeros(self.num_layers, x.size(0), self.hidden_size).to(x.device)
        out, _ = self.lstm(x, (h0, c0))
        out = self.fc(out[:, -1, :])
        return out

# Define model parameters
input_size = 1
hidden_size = 64
num_layers = 2
output_size = 1

# Instantiate the model
model = LSTMModel(input_size, hidden_size, num_layers, output_size)
print(model)
# Out:
# LSTMModel(
#   (lstm): LSTM(1, 64, num_layers=2, batch_first=True)
#   (fc): Linear(in_features=64, out_features=1, bias=True)
# )

# %% [markdown]
# #### Train Model

# %%
# Define training parameters
num_epochs = 200
learning_rate = 0.001
batch_size = 32
criterion = nn.MSELoss()
optimizer = torch.optim.Adam(model.parameters(), lr=learning_rate)

# Store losses
losses = []

# Training loop
for epoch in range(num_epochs):
    
    epoch_loss = 0.0
    
    # Shuffle the data and split into batches
    indices = torch.randperm(len(X_tensor))
    X_shuffled = X_tensor[indices]
    y_shuffled = y_tensor[indices]
    
    for i in range(0, len(X_tensor), batch_size):
        
        # Forward pass
        outputs = model(X_shuffled[i:i+batch_size])
        loss = criterion(outputs, y_shuffled[i:i+batch_size])
        
        # Backward pass and optimization
        optimizer.zero_grad()
        loss.backward()
        optimizer.step()
        
        # Accumulate loss for the epoch
        epoch_loss += loss.item()
    
    # Average epoch loss
    epoch_loss /= (len(X_tensor) / batch_size)
    losses.append(epoch_loss)
    
    if (epoch+1) % 1 == 0:
        print(f'Epoch [{epoch+1}/{num_epochs}], MSE Loss: {epoch_loss:.6f}')
# Out:
# Epoch [1/200], MSE Loss: 36.533316
# Epoch [2/200], MSE Loss: 3.161378
# Epoch [3/200], MSE Loss: 2.685165
# Epoch [4/200], MSE Loss: 2.518528
# Epoch [5/200], MSE Loss: 2.516070
# Epoch [6/200], MSE Loss: 2.518018
# Epoch [7/200], MSE Loss: 2.519128
# Epoch [8/200], MSE Loss: 2.537170
# Epoch [9/200], MSE Loss: 2.518745
# Epoch [10/200], MSE Loss: 2.546916
# Epoch [11/200], MSE Loss: 2.519309
# Epoch [12/200], MSE Loss: 2.517319
# Epoch [13/200], MSE Loss: 2.488026
# Epoch [14/200], MSE Loss: 2.354478
# Epoch [15/200], MSE Loss: 1.661466
# Epoch [16/200], MSE Loss: 1.162501
# Epoch [17/200], MSE Loss: 0.898827
# Epoch [18/200], MSE Loss: 0.705897
# Epoch [19/200], MSE Loss: 0.557393
# Epoch [20/200], MSE Loss: 0.446603
# Epoch [21/200], MSE Loss: 0.354706
# Epoch [22/200], MSE Loss: 0.284606
# Epoch [23/200], MSE Loss: 0.226971
# Epoch [24/200], MSE Loss: 0.184031
# Epoch [25/200], MSE Loss: 0.148782
# Epoch [26/200], MSE Loss: 0.118345
# Epoch [27/200], MSE Loss: 0.097152
# Epoch [28/200], MSE Loss: 0.078540
# Epoch [29/200], MSE Loss: 0.062530
# Epoch [30/200], MSE Loss: 0.051413
# Epoch [31/200], MSE Loss: 0.046003
# Epoch [32/200], MSE Loss: 0.034238
# Epoch [33/200], MSE Loss: 0.026823
# Epoch [34/200], MSE Loss: 0.025751
# Epoch [35/200], MSE Loss: 0.021308
# Epoch [36/200], MSE Loss: 0.016524
# Epoch [37/200], MSE Loss: 0.013976
# Epoch [38/200], MSE Loss: 0.011198
# Epoch [39/200], MSE Loss: 0.012206
# Epoch [40/200], MSE Loss: 0.007486
# Epoch [41/200], MSE Loss: 0.005363
# Epoch [42/200], MSE Loss: 0.004353
# Epoch [43/200], MSE Loss: 0.003465
# Epoch [44/200], MSE Loss: 0.003534
# Epoch [45/200], MSE Loss: 0.003692
# Epoch [46/200], MSE Loss: 0.003818
# Epoch [47/200], MSE Loss: 0.002739
# Epoch [48/200], MSE Loss: 0.002402
# Epoch [49/200], MSE Loss: 0.003061
# Epoch [50/200], MSE Loss: 0.002752
# Epoch [51/200], MSE Loss: 0.002100
# Epoch [52/200], MSE Loss: 0.008344
# Epoch [53/200], MSE Loss: 0.007259
# Epoch [54/200], MSE Loss: 0.016213
# Epoch [55/200], MSE Loss: 0.006428
# Epoch [56/200], MSE Loss: 0.001753
# Epoch [57/200], MSE Loss: 0.001476
# Epoch [58/200], MSE Loss: 0.001023
# Epoch [59/200], MSE Loss: 0.001879
# Epoch [60/200], MSE Loss: 0.013114
# Epoch [61/200], MSE Loss: 0.003542
# Epoch [62/200], MSE Loss: 0.000916
# Epoch [63/200], MSE Loss: 0.000736
# Epoch [64/200], MSE Loss: 0.000722
# Epoch [65/200], MSE Loss: 0.000868
# Epoch [66/200], MSE Loss: 0.000540
# Epoch [67/200], MSE Loss: 0.000952
# Epoch [68/200], MSE Loss: 0.000522
# Epoch [69/200], MSE Loss: 0.000456
# Epoch [70/200], MSE Loss: 0.000913
# Epoch [71/200], MSE Loss: 0.000900
# Epoch [72/200], MSE Loss: 0.000545
# Epoch [73/200], MSE Loss: 0.000897
# Epoch [74/200], MSE Loss: 0.000757
# Epoch [75/200], MSE Loss: 0.000724
# Epoch [76/200], MSE Loss: 0.000961
# Epoch [77/200], MSE Loss: 0.000903
# Epoch [78/200], MSE Loss: 0.000781
# Epoch [79/200], MSE Loss: 0.000412
# Epoch [80/200], MSE Loss: 0.000703
# Epoch [81/200], MSE Loss: 0.001767
# Epoch [82/200], MSE Loss: 0.002036
# Epoch [83/200], MSE Loss: 0.000999
# Epoch [84/200], MSE Loss: 0.004124
# Epoch [85/200], MSE Loss: 0.001929
# Epoch [86/200], MSE Loss: 0.001165
# Epoch [87/200], MSE Loss: 0.000907
# Epoch [88/200], MSE Loss: 0.001444
# Epoch [89/200], MSE Loss: 0.000809
# Epoch [90/200], MSE Loss: 0.001087
# Epoch [91/200], MSE Loss: 0.005866
# Epoch [92/200], MSE Loss: 0.001316
# Epoch [93/200], MSE Loss: 0.000967
# Epoch [94/200], MSE Loss: 0.000945
# Epoch [95/200], MSE Loss: 0.000588
# Epoch [96/200], MSE Loss: 0.000961
# Epoch [97/200], MSE Loss: 0.001404
# Epoch [98/200], MSE Loss: 0.000502
# Epoch [99/200], MSE Loss: 0.001235
# Epoch [100/200], MSE Loss: 0.000973
# Epoch [101/200], MSE Loss: 0.000498
# Epoch [102/200], MSE Loss: 0.000457
# Epoch [103/200], MSE Loss: 0.002254
# Epoch [104/200], MSE Loss: 0.002605
# Epoch [105/200], MSE Loss: 0.000798
# Epoch [106/200], MSE Loss: 0.000697
# Epoch [107/200], MSE Loss: 0.001783
# Epoch [108/200], MSE Loss: 0.000382
# Epoch [109/200], MSE Loss: 0.000313
# Epoch [110/200], MSE Loss: 0.002963
# Epoch [111/200], MSE Loss: 0.003162
# Epoch [112/200], MSE Loss: 0.000586
# Epoch [113/200], MSE Loss: 0.000313
# Epoch [114/200], MSE Loss: 0.000413
# Epoch [115/200], MSE Loss: 0.000283
# Epoch [116/200], MSE Loss: 0.000300
# Epoch [117/200], MSE Loss: 0.001172
# Epoch [118/200], MSE Loss: 0.003275
# Epoch [119/200], MSE Loss: 0.009667
# Epoch [120/200], MSE Loss: 0.001541
# Epoch [121/200], MSE Loss: 0.000646
# Epoch [122/200], MSE Loss: 0.000647
# Epoch [123/200], MSE Loss: 0.000993
# Epoch [124/200], MSE Loss: 0.000338
# Epoch [125/200], MSE Loss: 0.000722
# Epoch [126/200], MSE Loss: 0.000338
# Epoch [127/200], MSE Loss: 0.000564
# Epoch [128/200], MSE Loss: 0.000267
# Epoch [129/200], MSE Loss: 0.000224
# Epoch [130/200], MSE Loss: 0.000637
# Epoch [131/200], MSE Loss: 0.001044
# Epoch [132/200], MSE Loss: 0.002443
# Epoch [133/200], MSE Loss: 0.001541
# Epoch [134/200], MSE Loss: 0.000844
# Epoch [135/200], MSE Loss: 0.001055
# Epoch [136/200], MSE Loss: 0.001218
# Epoch [137/200], MSE Loss: 0.000656
# Epoch [138/200], MSE Loss: 0.000512
# Epoch [139/200], MSE Loss: 0.000228
# Epoch [140/200], MSE Loss: 0.001408
# Epoch [141/200], MSE Loss: 0.000647
# Epoch [142/200], MSE Loss: 0.001843
# Epoch [143/200], MSE Loss: 0.006948
# Epoch [144/200], MSE Loss: 0.007236
# Epoch [145/200], MSE Loss: 0.000502
# Epoch [146/200], MSE Loss: 0.001392
# Epoch [147/200], MSE Loss: 0.001138
# Epoch [148/200], MSE Loss: 0.000503
# Epoch [149/200], MSE Loss: 0.000403
# Epoch [150/200], MSE Loss: 0.000351
# Epoch [151/200], MSE Loss: 0.000170
# Epoch [152/200], MSE Loss: 0.000352
# Epoch [153/200], MSE Loss: 0.001030
# Epoch [154/200], MSE Loss: 0.000436
# Epoch [155/200], MSE Loss: 0.000348
# Epoch [156/200], MSE Loss: 0.000178
# Epoch [157/200], MSE Loss: 0.000249
# Epoch [158/200], MSE Loss: 0.000728
# Epoch [159/200], MSE Loss: 0.000527
# Epoch [160/200], MSE Loss: 0.001474
# Epoch [161/200], MSE Loss: 0.000393
# Epoch [162/200], MSE Loss: 0.000217
# Epoch [163/200], MSE Loss: 0.000200
# Epoch [164/200], MSE Loss: 0.001372
# Epoch [165/200], MSE Loss: 0.000399
# Epoch [166/200], MSE Loss: 0.000623
# Epoch [167/200], MSE Loss: 0.002855
# Epoch [168/200], MSE Loss: 0.000424
# Epoch [169/200], MSE Loss: 0.000526
# Epoch [170/200], MSE Loss: 0.000624
# Epoch [171/200], MSE Loss: 0.000361
# Epoch [172/200], MSE Loss: 0.000585
# Epoch [173/200], MSE Loss: 0.000315
# Epoch [174/200], MSE Loss: 0.000716
# Epoch [175/200], MSE Loss: 0.009106
# Epoch [176/200], MSE Loss: 0.002338
# Epoch [177/200], MSE Loss: 0.000933
# Epoch [178/200], MSE Loss: 0.000645
# Epoch [179/200], MSE Loss: 0.000390
# Epoch [180/200], MSE Loss: 0.000220
# Epoch [181/200], MSE Loss: 0.000223
# Epoch [182/200], MSE Loss: 0.000280
# Epoch [183/200], MSE Loss: 0.003316
# Epoch [184/200], MSE Loss: 0.000422
# Epoch [185/200], MSE Loss: 0.001080
# Epoch [186/200], MSE Loss: 0.000553
# Epoch [187/200], MSE Loss: 0.002718
# Epoch [188/200], MSE Loss: 0.001144
# Epoch [189/200], MSE Loss: 0.000206
# Epoch [190/200], MSE Loss: 0.000190
# Epoch [191/200], MSE Loss: 0.000425
# Epoch [192/200], MSE Loss: 0.000421
# Epoch [193/200], MSE Loss: 0.000289
# Epoch [194/200], MSE Loss: 0.000485
# Epoch [195/200], MSE Loss: 0.000292
# Epoch [196/200], MSE Loss: 0.000305
# Epoch [197/200], MSE Loss: 0.000967
# Epoch [198/200], MSE Loss: 0.000896
# Epoch [199/200], MSE Loss: 0.000501
# Epoch [200/200], MSE Loss: 0.000152

# %%
# Plot learning curve
offset = 30

plt.figure(figsize=(10, 6))
plt.plot(range(offset+1, num_epochs+1), losses[offset:], linestyle='-')
plt.title('Training Loss Curve')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.grid(True)
plt.show()

# %% [markdown]
# #### Evaluate Model

# %%
# Prepare the first sequence for prediction
first_sequence = torch.FloatTensor(series_data[:sequence_length]).unsqueeze(0).unsqueeze(-1)

# Make predictions for the entire time series
with torch.no_grad():
    future_periods = len(series_data) - sequence_length
    future_data = series_data[:sequence_length].tolist()

    for i in range(future_periods):
        pred = model(first_sequence)
        future_data.append(pred.item())
        
        # Update the first sequence for the next prediction
        first_sequence = torch.cat((first_sequence[:, 1:, :], pred.unsqueeze(-1)), dim=1)

# Plot the original and predicted sales data
plt.figure(figsize=(10, 6))
plt.plot(np.arange(len(series_data)), series_data, linestyle='-', label='Simulation Data')
plt.plot(np.arange(len(series_data)), future_data, linestyle='--', color='g', label='Predicted Data')
plt.title('Sales Prediction with LSTM')
plt.xlabel('Period')
plt.ylabel('Sales')
plt.legend()
plt.grid(True)
plt.show()

# %%
# Calculate Mean Squared Error (MSE)
mse = mean_squared_error(series_data[sequence_length:], future_data[sequence_length:])
print("Mean Squared Error (MSE):", mse)

# Calculate Mean Absolute Error (MAE)
mae = mean_absolute_error(series_data[sequence_length:], future_data[sequence_length:])
print("Mean Absolute Error (MAE):", mae)
# Out:
# Mean Squared Error (MSE): 10.77930744302123
# Mean Absolute Error (MAE): 2.8946585158876252

# %% [markdown]
# ---
