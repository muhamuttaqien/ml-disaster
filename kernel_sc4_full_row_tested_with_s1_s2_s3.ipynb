# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

import torch
import torch.nn as nn
import torch.nn.functional as F

from sklearn.metrics import mean_absolute_error, mean_squared_error

# %%
plt.style.use('ggplot')

# %% [markdown]
# ## Load Data

# %%
data_path = "./per_station.xlsx"
data = pd.read_excel(data_path)

# Extract the 'sc4' column data
sc_data = data['sc4'].values

# %%
# Generate dummy data
series_data = sc_data[:]

# Plot the dummy data
plt.figure(figsize=(10, 6))
plt.plot(series_data, linestyle='-')
plt.title('Tsunami Simulation Data (Scenario 4)')
plt.xlabel('Period')
plt.ylabel('Attribute')
plt.grid(True)
plt.show()

# %% [markdown]
# ## Prepare Data

# %%
def prepare_data(data, seq_length):
    X, y = [], []
    for i in range(len(data) - seq_length):
        X.append(data[i:i+seq_length])
        y.append(data[i+seq_length])
    return np.array(X), np.array(y)

# Define sequence length
sequence_length = 20

# Prepare the data
X, y = prepare_data(series_data, sequence_length)

# Convert to PyTorch tensors
X_tensor = torch.Tensor(X).unsqueeze(-1)  # Add an extra dimension for the input channel
y_tensor = torch.Tensor(y).unsqueeze(-1)

# %% [markdown]
# ## LSTM Experiment

# %% [markdown]
# #### Build Model

# %%
class LSTMModel(nn.Module):
    def __init__(self, input_size, hidden_size, num_layers, output_size):
        super(LSTMModel, self).__init__()
        self.hidden_size = hidden_size
        self.num_layers = num_layers
        self.lstm = nn.LSTM(input_size, hidden_size, num_layers, batch_first=True)
        self.dropout = nn.Dropout(0.5)
        self.fc = nn.Linear(hidden_size, output_size)
    
    def forward(self, x):
        h0 = torch.zeros(self.num_layers, x.size(0), self.hidden_size).to(x.device)
        c0 = torch.zeros(self.num_layers, x.size(0), self.hidden_size).to(x.device)
        out, _ = self.lstm(x, (h0, c0))
        out = self.fc(out[:, -1, :])
        return out

# Define model parameters
input_size = 1
hidden_size = 32
num_layers = 2
output_size = 1

# Instantiate the model
model = LSTMModel(input_size, hidden_size, num_layers, output_size)
print(model)
# Out:
# LSTMModel(
#   (lstm): LSTM(1, 32, num_layers=2, batch_first=True)
#   (dropout): Dropout(p=0.5, inplace=False)
#   (fc): Linear(in_features=32, out_features=1, bias=True)
# )

# %% [markdown]
# #### Train Model

# %%
# Define training parameters
num_epochs = 200
learning_rate = 0.001
batch_size = 32
criterion = nn.MSELoss()
optimizer = torch.optim.Adam(model.parameters(), lr=learning_rate)

# Store losses
losses = []

# Initialize the best loss as infinity
best_loss = float('inf')

# Training loop
for epoch in range(num_epochs):
    
    epoch_loss = 0.0
    
    # Shuffle the data and split into batches
    indices = torch.randperm(len(X_tensor))
    X_shuffled = X_tensor[indices]
    y_shuffled = y_tensor[indices]
    
    for i in range(0, len(X_tensor), batch_size):
        
        # Forward pass
        outputs = model(X_shuffled[i:i+batch_size])
        loss = criterion(outputs, y_shuffled[i:i+batch_size])
        
        # Backward pass and optimization
        optimizer.zero_grad()
        loss.backward()
        optimizer.step()
        
        # Accumulate loss for the epoch
        epoch_loss += loss.item()
    
    # Average epoch loss
    epoch_loss /= (len(X_tensor) / batch_size)
    losses.append(epoch_loss)
    
    # Save the model if this epoch's loss is the best we've seen so far
    if epoch_loss < best_loss:
        best_loss = epoch_loss
        torch.save(model.state_dict(), 'best_model.pth')

    if (epoch+1) % 1 == 0:
        print(f'Epoch [{epoch+1}/{num_epochs}], MSE Loss: {epoch_loss:.6f}')
# Out:
# Epoch [1/200], MSE Loss: 20.776146
# Epoch [2/200], MSE Loss: 0.420863
# Epoch [3/200], MSE Loss: 0.320105
# Epoch [4/200], MSE Loss: 0.285056
# Epoch [5/200], MSE Loss: 0.262443
# Epoch [6/200], MSE Loss: 0.242885
# Epoch [7/200], MSE Loss: 0.224486
# Epoch [8/200], MSE Loss: 0.206730
# Epoch [9/200], MSE Loss: 0.189626
# Epoch [10/200], MSE Loss: 0.173068
# Epoch [11/200], MSE Loss: 0.156483
# Epoch [12/200], MSE Loss: 0.139664
# Epoch [13/200], MSE Loss: 0.123695
# Epoch [14/200], MSE Loss: 0.108250
# Epoch [15/200], MSE Loss: 0.094430
# Epoch [16/200], MSE Loss: 0.082692
# Epoch [17/200], MSE Loss: 0.068710
# Epoch [18/200], MSE Loss: 0.059448
# Epoch [19/200], MSE Loss: 0.046319
# Epoch [20/200], MSE Loss: 0.039985
# Epoch [21/200], MSE Loss: 0.032918
# Epoch [22/200], MSE Loss: 0.025207
# Epoch [23/200], MSE Loss: 0.018790
# Epoch [24/200], MSE Loss: 0.015265
# Epoch [25/200], MSE Loss: 0.012562
# Epoch [26/200], MSE Loss: 0.010999
# Epoch [27/200], MSE Loss: 0.009643
# Epoch [28/200], MSE Loss: 0.006870
# Epoch [29/200], MSE Loss: 0.007966
# Epoch [30/200], MSE Loss: 0.006281
# Epoch [31/200], MSE Loss: 0.004150
# Epoch [32/200], MSE Loss: 0.003834
# Epoch [33/200], MSE Loss: 0.004595
# Epoch [34/200], MSE Loss: 0.004406
# Epoch [35/200], MSE Loss: 0.004120
# Epoch [36/200], MSE Loss: 0.004729
# Epoch [37/200], MSE Loss: 0.003741
# Epoch [38/200], MSE Loss: 0.004101
# Epoch [39/200], MSE Loss: 0.004472
# Epoch [40/200], MSE Loss: 0.005250
# Epoch [41/200], MSE Loss: 0.002502
# Epoch [42/200], MSE Loss: 0.004974
# Epoch [43/200], MSE Loss: 0.003832
# Epoch [44/200], MSE Loss: 0.003189
# Epoch [45/200], MSE Loss: 0.003261
# Epoch [46/200], MSE Loss: 0.003342
# Epoch [47/200], MSE Loss: 0.005715
# Epoch [48/200], MSE Loss: 0.003688
# Epoch [49/200], MSE Loss: 0.003026
# Epoch [50/200], MSE Loss: 0.003716
# Epoch [51/200], MSE Loss: 0.003055
# Epoch [52/200], MSE Loss: 0.003021
# Epoch [53/200], MSE Loss: 0.002741
# Epoch [54/200], MSE Loss: 0.003086
# Epoch [55/200], MSE Loss: 0.003746
# Epoch [56/200], MSE Loss: 0.003317
# Epoch [57/200], MSE Loss: 0.005564
# Epoch [58/200], MSE Loss: 0.007996
# Epoch [59/200], MSE Loss: 0.004075
# Epoch [60/200], MSE Loss: 0.004267
# Epoch [61/200], MSE Loss: 0.003957
# Epoch [62/200], MSE Loss: 0.003823
# Epoch [63/200], MSE Loss: 0.004474
# Epoch [64/200], MSE Loss: 0.003597
# Epoch [65/200], MSE Loss: 0.003488
# Epoch [66/200], MSE Loss: 0.003203
# Epoch [67/200], MSE Loss: 0.005196
# Epoch [68/200], MSE Loss: 0.004689
# Epoch [69/200], MSE Loss: 0.003077
# Epoch [70/200], MSE Loss: 0.002444
# Epoch [71/200], MSE Loss: 0.003232
# Epoch [72/200], MSE Loss: 0.002825
# Epoch [73/200], MSE Loss: 0.004178
# Epoch [74/200], MSE Loss: 0.003870
# Epoch [75/200], MSE Loss: 0.003078
# Epoch [76/200], MSE Loss: 0.002907
# Epoch [77/200], MSE Loss: 0.003305
# Epoch [78/200], MSE Loss: 0.002986
# Epoch [79/200], MSE Loss: 0.003269
# Epoch [80/200], MSE Loss: 0.003017
# Epoch [81/200], MSE Loss: 0.003129
# Epoch [82/200], MSE Loss: 0.003166
# Epoch [83/200], MSE Loss: 0.003067
# Epoch [84/200], MSE Loss: 0.002541
# Epoch [85/200], MSE Loss: 0.002827
# Epoch [86/200], MSE Loss: 0.004624
# Epoch [87/200], MSE Loss: 0.002853
# Epoch [88/200], MSE Loss: 0.002403
# Epoch [89/200], MSE Loss: 0.003592
# Epoch [90/200], MSE Loss: 0.003024
# Epoch [91/200], MSE Loss: 0.003474
# Epoch [92/200], MSE Loss: 0.004078
# Epoch [93/200], MSE Loss: 0.002531
# Epoch [94/200], MSE Loss: 0.002951
# Epoch [95/200], MSE Loss: 0.002746
# Epoch [96/200], MSE Loss: 0.002585
# Epoch [97/200], MSE Loss: 0.002896
# Epoch [98/200], MSE Loss: 0.003023
# Epoch [99/200], MSE Loss: 0.002847
# Epoch [100/200], MSE Loss: 0.002647
# Epoch [101/200], MSE Loss: 0.004090
# Epoch [102/200], MSE Loss: 0.003312
# Epoch [103/200], MSE Loss: 0.003876
# Epoch [104/200], MSE Loss: 0.002692
# Epoch [105/200], MSE Loss: 0.003093
# Epoch [106/200], MSE Loss: 0.002964
# Epoch [107/200], MSE Loss: 0.002699
# Epoch [108/200], MSE Loss: 0.003049
# Epoch [109/200], MSE Loss: 0.002486
# Epoch [110/200], MSE Loss: 0.003163
# Epoch [111/200], MSE Loss: 0.002689
# Epoch [112/200], MSE Loss: 0.002642
# Epoch [113/200], MSE Loss: 0.002909
# Epoch [114/200], MSE Loss: 0.003182
# Epoch [115/200], MSE Loss: 0.002706
# Epoch [116/200], MSE Loss: 0.002922
# Epoch [117/200], MSE Loss: 0.002575
# Epoch [118/200], MSE Loss: 0.003021
# Epoch [119/200], MSE Loss: 0.003140
# Epoch [120/200], MSE Loss: 0.002958
# Epoch [121/200], MSE Loss: 0.003500
# Epoch [122/200], MSE Loss: 0.003057
# Epoch [123/200], MSE Loss: 0.002591
# Epoch [124/200], MSE Loss: 0.002635
# Epoch [125/200], MSE Loss: 0.002951
# Epoch [126/200], MSE Loss: 0.002977
# Epoch [127/200], MSE Loss: 0.003163
# Epoch [128/200], MSE Loss: 0.003097
# Epoch [129/200], MSE Loss: 0.002295
# Epoch [130/200], MSE Loss: 0.003070
# Epoch [131/200], MSE Loss: 0.003674
# Epoch [132/200], MSE Loss: 0.002866
# Epoch [133/200], MSE Loss: 0.001963
# Epoch [134/200], MSE Loss: 0.003221
# Epoch [135/200], MSE Loss: 0.003200
# Epoch [136/200], MSE Loss: 0.002348
# Epoch [137/200], MSE Loss: 0.002785
# Epoch [138/200], MSE Loss: 0.002257
# Epoch [139/200], MSE Loss: 0.002655
# Epoch [140/200], MSE Loss: 0.002870
# Epoch [141/200], MSE Loss: 0.002686
# Epoch [142/200], MSE Loss: 0.003911
# Epoch [143/200], MSE Loss: 0.003241
# Epoch [144/200], MSE Loss: 0.003341
# Epoch [145/200], MSE Loss: 0.003104
# Epoch [146/200], MSE Loss: 0.002355
# Epoch [147/200], MSE Loss: 0.002357
# Epoch [148/200], MSE Loss: 0.002842
# Epoch [149/200], MSE Loss: 0.002750
# Epoch [150/200], MSE Loss: 0.002967
# Epoch [151/200], MSE Loss: 0.002218
# Epoch [152/200], MSE Loss: 0.003076
# Epoch [153/200], MSE Loss: 0.002526
# Epoch [154/200], MSE Loss: 0.001851
# Epoch [155/200], MSE Loss: 0.002501
# Epoch [156/200], MSE Loss: 0.003110
# Epoch [157/200], MSE Loss: 0.002976
# Epoch [158/200], MSE Loss: 0.002870
# Epoch [159/200], MSE Loss: 0.004199
# Epoch [160/200], MSE Loss: 0.002324
# Epoch [161/200], MSE Loss: 0.002060
# Epoch [162/200], MSE Loss: 0.002528
# Epoch [163/200], MSE Loss: 0.003042
# Epoch [164/200], MSE Loss: 0.001988
# Epoch [165/200], MSE Loss: 0.002909
# Epoch [166/200], MSE Loss: 0.003357
# Epoch [167/200], MSE Loss: 0.003573
# Epoch [168/200], MSE Loss: 0.003398
# Epoch [169/200], MSE Loss: 0.002972
# Epoch [170/200], MSE Loss: 0.002791
# Epoch [171/200], MSE Loss: 0.002703
# Epoch [172/200], MSE Loss: 0.002163
# Epoch [173/200], MSE Loss: 0.003050
# Epoch [174/200], MSE Loss: 0.002795
# Epoch [175/200], MSE Loss: 0.002542
# Epoch [176/200], MSE Loss: 0.002878
# Epoch [177/200], MSE Loss: 0.002681
# Epoch [178/200], MSE Loss: 0.002664
# Epoch [179/200], MSE Loss: 0.002352
# Epoch [180/200], MSE Loss: 0.002581
# Epoch [181/200], MSE Loss: 0.002568
# Epoch [182/200], MSE Loss: 0.002677
# Epoch [183/200], MSE Loss: 0.002415
# Epoch [184/200], MSE Loss: 0.002158
# Epoch [185/200], MSE Loss: 0.002759
# Epoch [186/200], MSE Loss: 0.003038
# Epoch [187/200], MSE Loss: 0.002635
# Epoch [188/200], MSE Loss: 0.002256
# Epoch [189/200], MSE Loss: 0.002789
# Epoch [190/200], MSE Loss: 0.002089
# Epoch [191/200], MSE Loss: 0.002615
# Epoch [192/200], MSE Loss: 0.002435
# Epoch [193/200], MSE Loss: 0.002214
# Epoch [194/200], MSE Loss: 0.002473
# Epoch [195/200], MSE Loss: 0.001478
# Epoch [196/200], MSE Loss: 0.003563
# Epoch [197/200], MSE Loss: 0.002725
# Epoch [198/200], MSE Loss: 0.002048
# Epoch [199/200], MSE Loss: 0.002976
# Epoch [200/200], MSE Loss: 0.002632

# %%
# Plot learning curve
offset = 30

plt.figure(figsize=(10, 6))
plt.plot(range(offset+1, num_epochs+1), losses[offset:], linestyle='-')
plt.title('Training Loss Curve')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.grid(True)
plt.show()

# %% [markdown]
# #### Evaluate Model

# %%
# Prepare the first sequence for prediction
first_sequence = torch.FloatTensor(series_data[:sequence_length]).unsqueeze(0).unsqueeze(-1)

# Make predictions for the entire time series
with torch.no_grad():
    future_periods = len(series_data) - sequence_length
    future_data = series_data[:sequence_length].tolist()

    for i in range(future_periods):
        pred = model(first_sequence)
        future_data.append(pred.item())
        
        # Update the first sequence for the next prediction
        # first_sequence = torch.cat((first_sequence[:, 1:, :], pred.unsqueeze(-1)), dim=1)
        first_sequence = torch.cat((first_sequence[:, 1:, :], torch.tensor([[series_data[i+sequence_length]]], dtype=torch.float32).unsqueeze(0)), dim=1)
        
# Plot the original and predicted simulation data
plt.figure(figsize=(10, 6))
plt.plot(np.arange(len(series_data)), series_data, linestyle='-', label='Simulation Data')
plt.plot(np.arange(len(series_data)), future_data, linestyle='--', color='g', label='Predicted Data')
plt.title('Tsunami Simulation Data Prediction with LSTM')
plt.xlabel('Period')
plt.ylabel('Attribute')
plt.legend()
plt.grid(True)
plt.show()

# %%
# Plot the original and predicted simulation data
plt.figure(figsize=(10, 6))
plt.plot(np.arange(len(series_data[:3000])), series_data[:3000], linestyle='-', label='Simulation Data')
plt.plot(np.arange(len(series_data[:3000])), future_data[:3000], linestyle='--', color='g', label='Predicted Data')
plt.title('Tsunami Simulation Data Prediction with LSTM')
plt.xlabel('Period')
plt.ylabel('Attribute')
plt.legend()
plt.grid(True)
plt.show()

# %%
# Calculate Mean Squared Error (MSE)
mse = mean_squared_error(series_data[sequence_length:], future_data[sequence_length:])
print("Mean Squared Error (MSE):", mse)

# Calculate Mean Absolute Error (MAE)
mae = mean_absolute_error(series_data[sequence_length:], future_data[sequence_length:])
print("Mean Absolute Error (MAE):", mae)
# Out:
# Mean Squared Error (MSE): 0.0014217020566511943
# Mean Absolute Error (MAE): 0.0038088097383069826

# %% [markdown]
# ## Test S1, S2, S3

# %%
sc_data = data['sc1'].values
series_data = sc_data[:]

# %%
# Prepare the first sequence for prediction
first_sequence = torch.FloatTensor(series_data[:sequence_length]).unsqueeze(0).unsqueeze(-1)

# Make predictions for the entire time series
with torch.no_grad():
    future_periods = len(series_data) - sequence_length
    future_data = series_data[:sequence_length].tolist()

    for i in range(future_periods):
        pred = model(first_sequence)
        future_data.append(pred.item())
        
        # Update the first sequence for the next prediction
        # first_sequence = torch.cat((first_sequence[:, 1:, :], pred.unsqueeze(-1)), dim=1)
        first_sequence = torch.cat((first_sequence[:, 1:, :], torch.tensor([[series_data[i+sequence_length]]], dtype=torch.float32).unsqueeze(0)), dim=1)
        
# Plot the original and predicted simulation data
plt.figure(figsize=(10, 6))
plt.plot(np.arange(len(series_data)), series_data, linestyle='-', label='Simulation Data')
plt.plot(np.arange(len(series_data)), future_data, linestyle='--', color='g', label='Predicted Data')
plt.title('Tsunami Simulation Data Prediction with LSTM (SC1)')
plt.xlabel('Period')
plt.ylabel('Attribute')
plt.legend()
plt.grid(True)
plt.show()

# Plot the original and predicted simulation data
plt.figure(figsize=(10, 6))
plt.plot(np.arange(len(series_data[:3000])), series_data[:3000], linestyle='-', label='Simulation Data')
plt.plot(np.arange(len(series_data[:3000])), future_data[:3000], linestyle='--', color='g', label='Predicted Data')
plt.title('Tsunami Simulation Data Prediction with LSTM (SC1)')
plt.xlabel('Period')
plt.ylabel('Attribute')
plt.legend()
plt.grid(True)
plt.show()

# %%
# Calculate Mean Squared Error (MSE)
mse = mean_squared_error(series_data[sequence_length:], future_data[sequence_length:])
print("SC1 Mean Squared Error (MSE):", mse)

# Calculate Mean Absolute Error (MAE)
mae = mean_absolute_error(series_data[sequence_length:], future_data[sequence_length:])
print("SC1 Mean Absolute Error (MAE):", mae)
# Out:
# SC1 Mean Squared Error (MSE): 0.00602318213245091
# SC1 Mean Absolute Error (MAE): 0.006688431643427765

# %%
sc_data = data['sc2'].values
series_data = sc_data[:]

# %%
# Prepare the first sequence for prediction
first_sequence = torch.FloatTensor(series_data[:sequence_length]).unsqueeze(0).unsqueeze(-1)

# Make predictions for the entire time series
with torch.no_grad():
    future_periods = len(series_data) - sequence_length
    future_data = series_data[:sequence_length].tolist()

    for i in range(future_periods):
        pred = model(first_sequence)
        future_data.append(pred.item())
        
        # Update the first sequence for the next prediction
        # first_sequence = torch.cat((first_sequence[:, 1:, :], pred.unsqueeze(-1)), dim=1)
        first_sequence = torch.cat((first_sequence[:, 1:, :], torch.tensor([[series_data[i+sequence_length]]], dtype=torch.float32).unsqueeze(0)), dim=1)
        
# Plot the original and predicted simulation data
plt.figure(figsize=(10, 6))
plt.plot(np.arange(len(series_data)), series_data, linestyle='-', label='Simulation Data')
plt.plot(np.arange(len(series_data)), future_data, linestyle='--', color='g', label='Predicted Data')
plt.title('Tsunami Simulation Data Prediction with LSTM (SC2)')
plt.xlabel('Period')
plt.ylabel('Attribute')
plt.legend()
plt.grid(True)
plt.show()

# Plot the original and predicted simulation data
plt.figure(figsize=(10, 6))
plt.plot(np.arange(len(series_data[:3000])), series_data[:3000], linestyle='-', label='Simulation Data')
plt.plot(np.arange(len(series_data[:3000])), future_data[:3000], linestyle='--', color='g', label='Predicted Data')
plt.title('Tsunami Simulation Data Prediction with LSTM (SC2)')
plt.xlabel('Period')
plt.ylabel('Attribute')
plt.legend()
plt.grid(True)
plt.show()

# %%
# Calculate Mean Squared Error (MSE)
mse = mean_squared_error(series_data[sequence_length:], future_data[sequence_length:])
print("SC2 Mean Squared Error (MSE):", mse)

# Calculate Mean Absolute Error (MAE)
mae = mean_absolute_error(series_data[sequence_length:], future_data[sequence_length:])
print("SC2 Mean Absolute Error (MAE):", mae)
# Out:
# SC2 Mean Squared Error (MSE): 0.007040239659865842
# SC2 Mean Absolute Error (MAE): 0.009110408995312812

# %%
sc_data = data['sc3'].values
series_data = sc_data[:]

# %%
# Prepare the first sequence for prediction
first_sequence = torch.FloatTensor(series_data[:sequence_length]).unsqueeze(0).unsqueeze(-1)

# Make predictions for the entire time series
with torch.no_grad():
    future_periods = len(series_data) - sequence_length
    future_data = series_data[:sequence_length].tolist()

    for i in range(future_periods):
        pred = model(first_sequence)
        future_data.append(pred.item())
        
        # Update the first sequence for the next prediction
        # first_sequence = torch.cat((first_sequence[:, 1:, :], pred.unsqueeze(-1)), dim=1)
        first_sequence = torch.cat((first_sequence[:, 1:, :], torch.tensor([[series_data[i+sequence_length]]], dtype=torch.float32).unsqueeze(0)), dim=1)
        
# Plot the original and predicted simulation data
plt.figure(figsize=(10, 6))
plt.plot(np.arange(len(series_data)), series_data, linestyle='-', label='Simulation Data')
plt.plot(np.arange(len(series_data)), future_data, linestyle='--', color='g', label='Predicted Data')
plt.title('Tsunami Simulation Data Prediction with LSTM (SC3)')
plt.xlabel('Period')
plt.ylabel('Attribute')
plt.legend()
plt.grid(True)
plt.show()

# Plot the original and predicted simulation data
plt.figure(figsize=(10, 6))
plt.plot(np.arange(len(series_data[:3000])), series_data[:3000], linestyle='-', label='Simulation Data')
plt.plot(np.arange(len(series_data[:3000])), future_data[:3000], linestyle='--', color='g', label='Predicted Data')
plt.title('Tsunami Simulation Data Prediction with LSTM (SC3)')
plt.xlabel('Period')
plt.ylabel('Attribute')
plt.legend()
plt.grid(True)
plt.show()

# %%
# Calculate Mean Squared Error (MSE)
mse = mean_squared_error(series_data[sequence_length:], future_data[sequence_length:])
print("SC3 Mean Squared Error (MSE):", mse)

# Calculate Mean Absolute Error (MAE)
mae = mean_absolute_error(series_data[sequence_length:], future_data[sequence_length:])
print("SC3 Mean Absolute Error (MAE):", mae)
# Out:
# SC3 Mean Squared Error (MSE): 0.04241065644930132
# SC3 Mean Absolute Error (MAE): 0.018753749233796392

# %% [markdown]
# ---
