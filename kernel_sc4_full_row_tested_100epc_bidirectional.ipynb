# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

import torch
import torch.nn as nn
import torch.nn.functional as F

from sklearn.metrics import mean_absolute_error, mean_squared_error

# %%
plt.style.use('ggplot')

# %% [markdown]
# ## Load Data

# %%
data_path = "./per_station.xlsx"
data = pd.read_excel(data_path)

# Extract the 'sc4' column data
sc_data = data['sc4'].values

# %%
# Generate dummy data
series_data = sc_data[:]

# Plot the dummy data
plt.figure(figsize=(10, 6))
plt.plot(series_data, linestyle='-')
plt.title('Tsunami Simulation Data (Scenario 4)')
plt.xlabel('Period')
plt.ylabel('Attribute')
plt.grid(True)
plt.show()

# %% [markdown]
# ## Prepare Data

# %%
def prepare_data(data, seq_length):
    X, y = [], []
    for i in range(len(data) - seq_length):
        X.append(data[i:i+seq_length])
        y.append(data[i+seq_length])
    return np.array(X), np.array(y)

# Define sequence length
sequence_length = 20

# Prepare the data
X, y = prepare_data(series_data, sequence_length)

# Convert to PyTorch tensors
X_tensor = torch.Tensor(X).unsqueeze(-1)  # Add an extra dimension for the input channel
y_tensor = torch.Tensor(y).unsqueeze(-1)

# %% [markdown]
# ## LSTM Experiment

# %% [markdown]
# #### Build Model

# %%
class BidirectionalLSTM(nn.Module):
    def __init__(self, input_size, hidden_size, num_layers, output_size):
        super(BidirectionalLSTM, self).__init__()
        self.hidden_size = hidden_size
        self.num_layers = num_layers
        # Define a list of bidirectional LSTM layers
        self.lstms = nn.ModuleList([nn.LSTM(input_size if i == 0 else hidden_size * 2, 
                                             hidden_size, 
                                             num_layers=1,  # Each layer in the stack is a single layer LSTM
                                             batch_first=True,
                                             bidirectional=True) for i in range(num_layers)])
        self.dropout = nn.Dropout(0.5)
        self.fc = nn.Linear(hidden_size * 2, output_size)  # Output size will be doubled due to bidirectional LSTM
    
    def forward(self, x):
        # Initialize hidden and cell states for each layer
        h0 = torch.zeros(self.num_layers * 2, x.size(0), self.hidden_size).to(x.device)  # Double the number of layers for bidirectional LSTM
        c0 = torch.zeros(self.num_layers * 2, x.size(0), self.hidden_size).to(x.device)
        
        # Forward pass through each LSTM layer in the stack
        for i, lstm in enumerate(self.lstms):
            out, _ = lstm(x if i == 0 else out, (h0[i:i+2], c0[i:i+2]))  # Pass input or previous layer's output to the next layer
            out = self.dropout(out)  # Apply dropout
        out = self.fc(out[:, -1, :])  # Take the output of the last time step and pass it through the fully connected layer
        return out

# Define model parameters
input_size = 1
hidden_size = 32
num_layers = 2  # Set the number of layers in the LSTM stack
output_size = 1

# Instantiate the model
model = BidirectionalLSTM(input_size, hidden_size, num_layers, output_size)
print(model)
# Out:
# BidirectionalLSTM(
#   (lstms): ModuleList(
#     (0): LSTM(1, 32, batch_first=True, bidirectional=True)
#     (1): LSTM(64, 32, batch_first=True, bidirectional=True)
#   )
#   (dropout): Dropout(p=0.5, inplace=False)
#   (fc): Linear(in_features=64, out_features=1, bias=True)
# )

# %% [markdown]
# #### Train Model

# %%
# Define training parameters
num_epochs = 100
learning_rate = 0.001
batch_size = 32
criterion = nn.MSELoss()
optimizer = torch.optim.Adam(model.parameters(), lr=learning_rate)

# Store losses
losses = []

# Initialize the best loss as infinity
best_loss = float('inf')

# Training loop
for epoch in range(num_epochs):
    
    epoch_loss = 0.0
    
    # Shuffle the data and split into batches
    indices = torch.randperm(len(X_tensor))
    X_shuffled = X_tensor[indices]
    y_shuffled = y_tensor[indices]
    
    for i in range(0, len(X_tensor), batch_size):
        
        # Forward pass
        outputs = model(X_shuffled[i:i+batch_size])
        loss = criterion(outputs, y_shuffled[i:i+batch_size])
        
        # Backward pass and optimization
        optimizer.zero_grad()
        loss.backward()
        optimizer.step()
        
        # Accumulate loss for the epoch
        epoch_loss += loss.item()
    
    # Average epoch loss
    epoch_loss /= (len(X_tensor) / batch_size)
    losses.append(epoch_loss)
    
    # Save the model if this epoch's loss is the best we've seen so far
    if epoch_loss < best_loss:
        best_loss = epoch_loss
        torch.save(model.state_dict(), 'best_model.pth')

    if (epoch+1) % 1 == 0:
        print(f'Epoch [{epoch+1}/{num_epochs}], MSE Loss: {epoch_loss:.6f}')
# Out:
# Epoch [1/100], MSE Loss: 15.799297
# Epoch [2/100], MSE Loss: 2.213502
# Epoch [3/100], MSE Loss: 2.136344
# Epoch [4/100], MSE Loss: 2.107262
# Epoch [5/100], MSE Loss: 2.121618
# Epoch [6/100], MSE Loss: 2.013905
# Epoch [7/100], MSE Loss: 2.030092
# Epoch [8/100], MSE Loss: 1.995939
# Epoch [9/100], MSE Loss: 1.982696
# Epoch [10/100], MSE Loss: 1.895257
# Epoch [11/100], MSE Loss: 1.850111
# Epoch [12/100], MSE Loss: 1.743651
# Epoch [13/100], MSE Loss: 1.763557
# Epoch [14/100], MSE Loss: 1.660779
# Epoch [15/100], MSE Loss: 1.625439
# Epoch [16/100], MSE Loss: 1.522057
# Epoch [17/100], MSE Loss: 1.492875
# Epoch [18/100], MSE Loss: 1.432887
# Epoch [19/100], MSE Loss: 1.353779
# Epoch [20/100], MSE Loss: 1.297072
# Epoch [21/100], MSE Loss: 1.262103
# Epoch [22/100], MSE Loss: 1.188228
# Epoch [23/100], MSE Loss: 1.138281
# Epoch [24/100], MSE Loss: 1.085100
# Epoch [25/100], MSE Loss: 1.043183
# Epoch [26/100], MSE Loss: 0.978217
# Epoch [27/100], MSE Loss: 0.973663
# Epoch [28/100], MSE Loss: 0.903908
# Epoch [29/100], MSE Loss: 0.837468
# Epoch [30/100], MSE Loss: 0.820910
# Epoch [31/100], MSE Loss: 0.775910
# Epoch [32/100], MSE Loss: 0.759981
# Epoch [33/100], MSE Loss: 0.704287
# Epoch [34/100], MSE Loss: 0.643888
# Epoch [35/100], MSE Loss: 0.628205
# Epoch [36/100], MSE Loss: 0.587539
# Epoch [37/100], MSE Loss: 0.544832
# Epoch [38/100], MSE Loss: 0.525635
# Epoch [39/100], MSE Loss: 0.500116
# Epoch [40/100], MSE Loss: 0.462194
# Epoch [41/100], MSE Loss: 0.433790
# Epoch [42/100], MSE Loss: 0.414892
# Epoch [43/100], MSE Loss: 0.382727
# Epoch [44/100], MSE Loss: 0.357714
# Epoch [45/100], MSE Loss: 0.342142
# Epoch [46/100], MSE Loss: 0.322588
# Epoch [47/100], MSE Loss: 0.291108
# Epoch [48/100], MSE Loss: 0.281650
# Epoch [49/100], MSE Loss: 0.260835
# Epoch [50/100], MSE Loss: 0.237802
# Epoch [51/100], MSE Loss: 0.212445
# Epoch [52/100], MSE Loss: 0.222592
# Epoch [53/100], MSE Loss: 0.192667
# Epoch [54/100], MSE Loss: 0.179205
# Epoch [55/100], MSE Loss: 0.167140
# Epoch [56/100], MSE Loss: 0.155866
# Epoch [57/100], MSE Loss: 0.145688
# Epoch [58/100], MSE Loss: 0.130043
# Epoch [59/100], MSE Loss: 0.133774
# Epoch [60/100], MSE Loss: 0.132850
# Epoch [61/100], MSE Loss: 0.126681
# Epoch [62/100], MSE Loss: 0.098529
# Epoch [63/100], MSE Loss: 0.076361
# Epoch [64/100], MSE Loss: 0.078838
# Epoch [65/100], MSE Loss: 0.079139
# Epoch [66/100], MSE Loss: 0.068342
# Epoch [67/100], MSE Loss: 0.081226
# Epoch [68/100], MSE Loss: 0.064300
# Epoch [69/100], MSE Loss: 0.067895
# Epoch [70/100], MSE Loss: 0.049614
# Epoch [71/100], MSE Loss: 0.063456
# Epoch [72/100], MSE Loss: 0.052473
# Epoch [73/100], MSE Loss: 0.053796
# Epoch [74/100], MSE Loss: 0.042983
# Epoch [75/100], MSE Loss: 0.049500
# Epoch [76/100], MSE Loss: 0.039574
# Epoch [77/100], MSE Loss: 0.038311
# Epoch [78/100], MSE Loss: 0.041627
# Epoch [79/100], MSE Loss: 0.045594
# Epoch [80/100], MSE Loss: 0.031336
# Epoch [81/100], MSE Loss: 0.036242
# Epoch [82/100], MSE Loss: 0.044122
# Epoch [83/100], MSE Loss: 0.038571
# Epoch [84/100], MSE Loss: 0.037470
# Epoch [85/100], MSE Loss: 0.032940
# Epoch [86/100], MSE Loss: 0.034383
# Epoch [87/100], MSE Loss: 0.040846
# Epoch [88/100], MSE Loss: 0.027553
# Epoch [89/100], MSE Loss: 0.040354
# Epoch [90/100], MSE Loss: 0.053553
# Epoch [91/100], MSE Loss: 0.030721
# Epoch [92/100], MSE Loss: 0.037661
# Epoch [93/100], MSE Loss: 0.038043
# Epoch [94/100], MSE Loss: 0.041839
# Epoch [95/100], MSE Loss: 0.036882
# Epoch [96/100], MSE Loss: 0.029038
# Epoch [97/100], MSE Loss: 0.029942
# Epoch [98/100], MSE Loss: 0.026525
# Epoch [99/100], MSE Loss: 0.040764
# Epoch [100/100], MSE Loss: 0.039374

# %%
# Plot learning curve
offset = 30

plt.figure(figsize=(10, 6))
plt.plot(range(offset+1, num_epochs+1), losses[offset:], linestyle='-')
plt.title('Training Loss Curve')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.grid(True)
plt.show()

# %% [markdown]
# #### Evaluate Model

# %%
# Prepare the first sequence for prediction
first_sequence = torch.FloatTensor(series_data[:sequence_length]).unsqueeze(0).unsqueeze(-1)

# Make predictions for the entire time series
with torch.no_grad():
    future_periods = len(series_data) - sequence_length
    future_data = series_data[:sequence_length].tolist()

    for i in range(future_periods):
        pred = model(first_sequence)
        future_data.append(pred.item())
        
        # Update the first sequence for the next prediction
        # first_sequence = torch.cat((first_sequence[:, 1:, :], pred.unsqueeze(-1)), dim=1)
        first_sequence = torch.cat((first_sequence[:, 1:, :], torch.tensor([[series_data[i+sequence_length]]], dtype=torch.float32).unsqueeze(0)), dim=1)
        
# Plot the original and predicted simulation data
plt.figure(figsize=(10, 6))
plt.plot(np.arange(len(series_data)), series_data, linestyle='-', label='Simulation Data')
plt.plot(np.arange(len(series_data)), future_data, linestyle='--', color='g', label='Predicted Data')
plt.title('Tsunami Simulation Data Prediction with LSTM')
plt.xlabel('Period')
plt.ylabel('Attribute')
plt.legend()
plt.grid(True)
plt.show()

# %%
# Plot the original and predicted simulation data
plt.figure(figsize=(10, 6))
plt.plot(np.arange(len(series_data[:3000])), series_data[:3000], linestyle='-', label='Simulation Data')
plt.plot(np.arange(len(series_data[:3000])), future_data[:3000], linestyle='--', color='g', label='Predicted Data')
plt.title('Tsunami Simulation Data Prediction with LSTM')
plt.xlabel('Period')
plt.ylabel('Attribute')
plt.legend()
plt.grid(True)
plt.show()

# %%
# Calculate Mean Squared Error (MSE)
mse = mean_squared_error(series_data[sequence_length:], future_data[sequence_length:])
print("Mean Squared Error (MSE):", mse)

# Calculate Mean Absolute Error (MAE)
mae = mean_absolute_error(series_data[sequence_length:], future_data[sequence_length:])
print("Mean Absolute Error (MAE):", mae)
# Out:
# Mean Squared Error (MSE): 0.026619250131228612
# Mean Absolute Error (MAE): 0.05567044860783538

# %% [markdown]
# ---
